# %%
#Import dependancies 

import pandas as pd

# %%
# Load 'Olympics.csv' file into df DataFrame
olympics_df = pd.read_csv("../Olympics.csv", encoding="utf-8")
olympics_df
# Out:
#              Nation  Population Exists Code  First_App  Medal  S_Medal  \
# 0       Afghanistan    35530081    YES  AFG       1936   0.14     0.14
# 1           Albania     2930187    YES  ALB       1972   0.00     0.00
# 2           Algeria    41318142    YES  ALG       1964   1.06     1.31
# 3    American Samoa       55641    YES  ASA       1988   0.00     0.00
# 4           Andorra       76965    YES  AND       1976   0.00     0.00
# ..              ...         ...    ...  ...        ...    ...      ...
# 221    Yemen, North     7160981     NO  YAR       1984   0.00     0.00
# 222    Yemen, South     2585484     NO  YMD       1988   0.00     0.00
# 223      Yugoslavia    23230000     NO  YUG       1920   3.13     5.63
# 224          Zambia    17094130    YES  ZAM       1964   0.15     0.15
# 225        Zimbabwe    16529904    YES  ZIM       1928   0.57     0.62
#
#      W_Medal  Apps  Medal.1  ...  L20_Apps  L20_Medal  L20_Gold  L20_Silver  \
# ...

# %%
# drop columns we dont want 

clean_olympics = olympics_df.drop(['Medal', 'S_Medal'], axis=1)

clean_olympics
